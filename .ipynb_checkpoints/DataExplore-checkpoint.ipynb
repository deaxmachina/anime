# %%
import pandas as pd 
import numpy as np
import collections
import re

import matplotlib.pyplot as plt
# %matplotlib inline

from bokeh.io import output_file, show, output_notebook
from bokeh.models import ColumnDataSource, RangeTool
from bokeh.palettes import Category20b, cividis, inferno
from bokeh.plotting import figure
from bokeh.transform import factor_cmap, cumsum
from bokeh.layouts import column
from math import pi

# %% [markdown]
# ## Helper Functions

# %%
def get_multiple_choice_counts_df(df, fields):
    multiple_choice = []
    for field in fields: 
        #pd.DataFrame(df[field].value_counts()).index.tolist()
        multiple_choice.extend(df[field].dropna().tolist())
    multiple_choice_list = []
    mchoice = [item.replace('。', '').strip() for item in multiple_choice]
    for item in mchoice: 
        multiple_choice_list.extend(item.split(', '))
    unique_values = list(set(multiple_choice_list)) 
    
    counter=collections.Counter(multiple_choice_list)
    mchoice_df = pd.DataFrame.from_dict(counter, orient='index').reset_index()
    mchoice_df.columns = ['field', 'freq']
    return mchoice_df.sort_values(by='freq', ascending=False)

# %% [markdown]
# ### Graphs

# %%
def line_range(dates, data, start_date_number=0, end_date_number=30, label="Label", line_colour="maroon"):
    source = ColumnDataSource(data=dict(date=dates, data=data))
    
    p = figure(plot_height=300, plot_width=1000, tools="xpan", toolbar_location=None,
           x_axis_type="datetime", x_axis_location="above",
           background_fill_color="#efefef", x_range=(dates[start_date_number], dates[end_date_number]))
    
    p.line('date', 'data', source=source, color=line_colour, line_width=2)
    p.yaxis.axis_label = label
    
    select = figure(title="Drag slider",
                plot_height=130, plot_width=1000, y_range=p.y_range,
                x_axis_type="datetime", y_axis_type=None,
                tools="", toolbar_location=None, 
                background_fill_color= "#2b2b2b")
                #background_fill_color="#efefef")
    
    range_tool = RangeTool(x_range=p.x_range)
    range_tool.overlay.fill_color = "white"
    range_tool.overlay.fill_alpha = 0.2
    
    select.line('date', 'data', source=source)
    select.ygrid.grid_line_color = None
    select.add_tools(range_tool)
    select.toolbar.active_multi = range_tool
    
    show(column(p, select))

# %%
data1 = pd.read_csv("anime.csv")

# %%
data1.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
data2 = pd.read_csv("dataanime.csv")

# %%
data2.head()
# Out:
#                               Title   Type Episodes            Status  \
# 0  Fullmetal Alchemist: Brotherhood     TV       64   Finished Airing
# 1                    Kimi no Na wa.  Movie        1   Finished Airing
# 2                          Gintama°     TV       51   Finished Airing
# 3                     Steins;Gate 0     TV       23  Currently Airing
# 4                       Steins;Gate     TV       24   Finished Airing
#
#   Start airing End airing Starting season             Broadcast time  \
# 0     2009-4-5   2010-7-4          Spring     Sundays at 17:00 (JST)
# 1    2016-8-26          -               -                          -
# 2     2015-4-8  2016-3-30          Spring  Wednesdays at 18:00 (JST)
# 3    2018-4-12          -          Spring   Thursdays at 01:35 (JST)
# 4     2011-4-6  2011-9-14          Spring  Wednesdays at 02:05 (JST)
#
#                                            Producers  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# 1  Kadokawa Shoten,Toho,Sound Team Don Juan,Lawso...
# 2                            TV Tokyo,Aniplex,Dentsu
# 3                                          Nitroplus
# 4  Frontier Works,Media Factory,Movic,AT-X,Kadoka...
#
#                        Licensors                Studios       Sources  \
# 0  Funimation,Aniplex of America                  Bones         Manga
# 1           Funimation,NYAV Post       CoMix Wave Films      Original
# 2         Funimation,Crunchyroll  Bandai Namco Pictures         Manga
# 3                     Funimation              White Fox  Visual novel
# 4                     Funimation              White Fox  Visual novel
#
#                                               Genres         Duration Rating  \
# 0  Action,Military,Adventure,Comedy,Drama,Magic,F...  24 min. per ep.      R
# 1                  Supernatural,Drama,Romance,School    1 hr. 46 min.  PG-13
# 2  Action,Comedy,Historical,Parody,Samurai,Sci-Fi...  24 min. per ep.      R
# 3                                    Sci-Fi,Thriller  23 min. per ep.  PG-13
# 4                                    Sci-Fi,Thriller  24 min. per ep.  PG-13
#
#    Score  Scored by  Members  Favorites  \
# 0   9.25     719706  1176368     105387
# 1   9.19     454969   705186      33936
# 2   9.16      70279   194359       5597
# 3   9.16      12609   186331       1117
# 4   9.14     552791   990419      90365
#
#                                          Description
# 0  "In order for something to be obtained, someth...
# 1  Mitsuha Miyamizu, a high school girl, yearns t...
# 2  Gintoki, Shinpachi, and Kagura return as the f...
# 3  The dark untold story of Steins;Gate that lead...
# 4  The self-proclaimed mad scientist Rintarou Oka...

# %%
len(data2)
# Out:
# 1563

# %%
# convert to datetimes for start and end 
data2['start_date'] = pd.to_datetime(data2['Start airing'],errors='coerce')
data2['end_date'] = pd.to_datetime(data2['End airing'],errors='coerce')

# %%
# remove the duplicates ans join 
data1 = data1.drop_duplicates(subset=["name"]).set_index("name")
data2 = data2.drop_duplicates(subset=["Title"]).set_index("Title")

# %%
# join the two dataframes
df = data1.join(data2, how="inner")

# %%
# add the year 
df['year'] = df['start_date'].dt.year
# keep only the anime that you have the data for 
df = df.dropna(subset=['year'])
df['year'] = df["year"].astype(int)

# %% [markdown]
# ### Genres

# %%
genres = get_multiple_choice_counts_df(df, ["genre"])

# %%
genres.head(5)
# Out:
#         field  freq
# 10     Comedy   636
# 4      Action   462
# 0       Drama   432
# 9     Shounen   380
# 5   Adventure   319

# %%
df_genres = []
for genre in genres['field'].tolist():
    df_genre = df[df['genre'].str.contains(genre)].groupby("year").count()[['anime_id']]
    df_genre.columns = [genre]
    df_genres.append(df_genre)

# %%
df_genres = pd.concat(df_genres, axis="columns")

# %%
df_genres.head()
# Out:
#       Comedy  Action  Drama  Shounen  Adventure  Romance  Fantasy  \
# year
# 1970     NaN     NaN    1.0      NaN        NaN      NaN      NaN
# 1971     1.0     1.0    NaN      1.0        1.0      NaN      NaN
# 1974     NaN     1.0    1.0      NaN        1.0      NaN      NaN
# 1975     NaN     NaN    NaN      1.0        NaN      NaN      NaN
# 1976     NaN     NaN    1.0      NaN        NaN      NaN      NaN
#
#       Supernatural  Slice of Life  Sci-Fi  ...  Samurai  Game  Vampire  \
# year                                       ...
# 1970           NaN            NaN     NaN  ...      NaN   NaN      NaN
# 1971           NaN            NaN     NaN  ...      NaN   NaN      NaN
# 1974           NaN            NaN     1.0  ...      NaN   NaN      NaN
# 1975           NaN            NaN     1.0  ...      NaN   NaN      NaN
# 1976           NaN            1.0     NaN  ...      NaN   NaN      NaN
#
#       Shounen Ai  Harem  Cars  Shoujo Ai  Dementia  Ecchi  Yaoi
# year
# 1970         NaN    NaN   NaN        NaN       NaN    NaN   NaN
# 1971         NaN    NaN   NaN        NaN       NaN    NaN   NaN
# 1974         NaN    NaN   NaN        NaN       NaN    NaN   NaN
# 1975         NaN    NaN   NaN        NaN       NaN    NaN   NaN
# 1976         NaN    NaN   NaN        NaN       NaN    NaN   NaN
#
# [5 rows x 41 columns]

# %%
def get_line_chart_per_genre(genre):
    porg = df_genres[[genre]].dropna()
    dates = np.array(porg.index.tolist())
    data = np.array(porg[genre])
    line_range(dates, data, 0, 30, label=genre, line_colour="deepskyblue")

# %%
for genre in genres.head(10)['field'].tolist():
    get_line_chart_per_genre(genre)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-813fab509199> in <module>
#       1 for genre in genres.head(10)['field'].tolist():
# ----> 2     get_line_chart_per_genre(genre)
#
# <ipython-input-97-b4939f497372> in get_line_chart_per_genre(genre)
#       3     dates = np.array(porg.index.tolist())
#       4     data = np.array(porg[genre])
# ----> 5     line_range(dates, data, 0, 30, label=genre, line_colour="deepskyblue")
#
# <ipython-input-87-fa2d8b7e4880> in line_range(dates, data, start_date_number, end_date_number, label, line_colour)
#       4     p = figure(plot_height=300, plot_width=1000, tools="xpan", toolbar_location=None,
#       5            x_axis_type="datetime", x_axis_location="above",
# ----> 6            background_fill_color="#efefef", x_range=(dates[start_date_number], dates[end_date_number]))
#       7
#       8     p.line('date', 'data', source=source, color=line_colour, line_width=2)
#
# IndexError: index 30 is out of bounds for axis 0 with size 23
